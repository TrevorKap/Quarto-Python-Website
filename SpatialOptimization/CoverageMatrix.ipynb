# %% [markdown]
# Maximize
# 27X1+694X2+32X3+X4+12X5+44X6+3X7+19X8
# Subject to:
# X1-(Y1+Y2+Y3)<=0
# X2-(Y1+Y3+Y4+Y7)<=0
# X3-(Y1+Y3+Y5)<=0
# X4-Y8<=0
# X5-(Y1+Y4)<=0
# X6-(Y1+Y2+Y4+Y6)<=0
# X7-(Y3+Y5+Y6+Y7)<=0
# X8-(Y3+Y4+Y7+Y8)<=0
# Y1+Y2+Y3+Y4+Y5+Y6+Y7+Y8<=5
# Binary
# X1
# X2
# X3
# X4
# X5
# X6
# X7
# X8
# Y1
# Y2
# Y3
# Y4
# Y5
# Y6
# Y7
# Y8
# End
